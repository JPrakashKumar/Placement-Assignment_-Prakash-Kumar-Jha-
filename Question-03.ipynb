# %%
import requests
import pandas as pd


# Download the data from the provided link
url = "https://raw.githubusercontent.com/Biuni/PokemonGO-Pokedex/master/pokedex.json"
response = requests.get(url)
data = response.json()


# Process the data and extract the required attributes

structured_data = []                 # Empty list created
for pokemon in data["pokemon"]:
    attributes = {
        "id": pokemon["id"],
        "num": pokemon["num"],
        "name": pokemon["name"],
        "img": pokemon["img"],
        "type": ", ".join(pokemon["type"]),
        "height": pokemon["height"],
        "weight": pokemon["weight"],
        "candy": pokemon.get("candy", ""),
        "candy_count": pokemon.get("candy_count", 0),
        "egg": pokemon.get("egg", ""),
        "spawn_chance": pokemon.get("spawn_chance", 0.0),
        "avg_spawns": pokemon.get("avg_spawns", 0),
        "spawn_time": pokemon.get("spawn_time", ""),
        "multipliers": ", ".join(str(m) for m in pokemon.get("multipliers", [])) if pokemon.get("multipliers") else "NaN",
        "weakness": ", ".join(pokemon.get("weaknesses", [])),
        "next_evolution": ", ".join(
            f"{e['num']} - {e['name']}" for e in pokemon.get("next_evolution", [])
        )if pokemon.get("next_evolution") else "NaN",
        "prev_evolution": ", ".join(
            f"{e['num']} - {e['name']}" for e in pokemon.get("prev_evolution", [])
        )if pokemon.get("prev_evolution") else "NaN",
    }
    structured_data.append(attributes)  # Adding all attributes data to empty list



# Convert structured data to a pandas DataFrame

df = pd.DataFrame(structured_data)



# Save the DataFrame to an Excel file

result = "pokemon_data.xlsx"
df.to_excel(result, index=False)

print(f"Data is successfully added to {result}")
# Out:
# Data is successfully added to pokemon_data.xlsx

# %%
import pandas as pd

df = pd.read_excel('pokemon_data.xlsx')

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)


df
# Out:
#       id  num                name
# 0      1    1           Bulbasaur  \
# 1      2    2             Ivysaur
# 2      3    3            Venusaur
# 3      4    4          Charmander
# 4      5    5          Charmeleon
# 5      6    6           Charizard
# 6      7    7            Squirtle
# 7      8    8           Wartortle
# 8      9    9           Blastoise
# 9     10   10            Caterpie
# 10    11   11             Metapod
# 11    12   12          Butterfree
# 12    13   13              Weedle
# 13    14   14              Kakuna
# 14    15   15            Beedrill
# 15    16   16              Pidgey
# 16    17   17           Pidgeotto
# 17    18   18             Pidgeot
# 18    19   19             Rattata
# 19    20   20            Raticate
# 20    21   21             Spearow
# 21    22   22              Fearow
# 22    23   23               Ekans
# 23    24   24               Arbok
# 24    25   25             Pikachu
# 25    26   26              Raichu
# ...

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# Print the DataFrame to view all table data
print(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 5
#       2 pd.set_option('display.max_columns', None)
#       4 # Print the DataFrame to view all table data
# ----> 5 print(df)
#
# NameError: name 'df' is not defined
